# %%
import os
import pandas as pd
from sqlalchemy import create_engine, MetaData, Table

# %%
dst_conn = create_engine(f'postgresql://mle_20240226_059a2462fd:3d6694d26e2343e6a39dcc691f26f92b@rc1b-uh7kdmcx67eomesf.mdb.yandexcloud.net:6432/playground_mle_20240226_059a2462fd')

# %%
df = pd.read_sql('select * from flats_buildings', dst_conn)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141362 entries, 0 to 141361
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   flat_id            141362 non-null  int64
#  1   floor              141362 non-null  int64
#  2   is_apartment       141362 non-null  int64
#  3   kitchen_area       141362 non-null  float64
#  4   living_area        141362 non-null  float64
#  5   rooms              141362 non-null  int64
#  6   studio             141362 non-null  int64
#  7   total_area         141362 non-null  float64
#  8   price              141362 non-null  int64
#  9   building_id        141362 non-null  int64
#  10  build_year         141362 non-null  int64
#  11  building_type_int  141362 non-null  int64
#  12  latitude           141362 non-null  float64
#  13  longitude          141362 non-null  float64
#  14  ceiling_height     141362 non-null  int64
#  15  flats_count        141362 non-null  int64
#  16  floors_total       141362 non-null  int64
#  17  has_elevator       141362 non-null  int64
# dtypes: float64(5), int64(13)
# memory usage: 19.4 MB

# %% [markdown]
# # Дубликаты

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Проверим наличие дубликатов без flat_id

# %%
df.drop('flat_id', axis=1).duplicated().sum()
# Out:
# 9116

# %% [markdown]
# Видно, что есть одинаковые квартиры с разными id. Напишем функцию для удаления дубликатов

# %%
def remove_duplicates(data: pd.DataFrame):
    feature_cols = data.columns.drop('flat_id').tolist()
    is_duplicated_features = data.duplicated(subset=feature_cols)
    data = data[~is_duplicated_features].reset_index(drop=True)
    return data

# %%
df = remove_duplicates(df)

# %%
df.drop('flat_id', axis=1).duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Пропуски

# %%
df.isnull().sum()
# Out:
# flat_id              0
# floor                0
# is_apartment         0
# kitchen_area         0
# living_area          0
# rooms                0
# studio               0
# total_area           0
# price                0
# building_id          0
# build_year           0
# building_type_int    0
# latitude             0
# longitude            0
# ceiling_height       0
# flats_count          0
# floors_total         0
# has_elevator         0
# dtype: int64

# %% [markdown]
# В данный момент пропусков не наблюдается, но на будущее напишем функцию для их заполнения. Некоторые столбцы хоть и имеют числовой тип относятся к категориальным, разделим их на две группы для заполнения медианой и модой.

# %%
def fill_missing_values(data: pd.DataFrame):
    cols_with_nans = data.isnull().sum()
    cols_with_nans = cols_with_nans[cols_with_nans > 0].index
    mode_col = ['is_apartment', 'has_elevator', 'building_type_int', 'rooms', 'floor', 'build_year', 'flats_count']
    for col in cols_with_nans:
        if col not in mode_col:
            fill_value = data[col].median()
        elif col in mode_col:
            fill_value = data[col].mode().iloc[0]
        data[col] = data[col].fillna(fill_value)
    return data

# %%
df = fill_missing_values(df)

# %%
df
# Out:
#         flat_id  floor  is_apartment  kitchen_area  living_area  rooms  \
# 0             0      9             0          9.90    19.900000      1
# 1             1      7             0          0.00    16.600000      1
# 2             2      9             0          9.00    32.000000      2
# 3             3      1             0         10.10    43.099998      3
# 4             4      3             0          3.00    14.000000      1
# ...         ...    ...           ...           ...          ...    ...
# 132241   141357     16             0         11.00    18.000000      1
# 132242   141358      5             0          5.28    28.330000      2
# 132243   141359      7             0          5.30    20.000000      1
# 132244   141360     15             0         13.80    33.700001      2
# 132245   141361     16             0          7.60    18.000000      1
#
#         studio  total_area     price  building_id  build_year  \
# 0            0   35.099998   9500000         6220        1965
# 1            0   43.000000  13500000        18012        2001
# 2            0   56.000000  13500000        17821        2000
# 3            0   76.000000  20000000        18579        2002
# 4            0   24.000000   5200000         9293        1971
# ...        ...         ...       ...          ...         ...
# 132241       0   42.000000  10500000        22455        2013
# 132242       0   41.110001   7400000         3162        1960
# 132243       0   31.500000   9700000         6513        1966
# 132244       0   65.300003  11750000        23952        2017
# 132245       0   38.000000   8000000        15104        1988
#
#         building_type_int   latitude  longitude  ceiling_height  flats_count  \
# 0                       6  55.717113  37.781120               3           84
# 1                       2  55.794849  37.608013               3           97
# 2                       4  55.740040  37.761742               3           80
# 3                       4  55.672016  37.570877               3          771
# 4                       1  55.808807  37.707306               3          208
# ...                   ...        ...        ...             ...          ...
# 132241                  4  55.626579  37.313503               3          672
# 132242                  1  55.727470  37.768677               2           80
# 132243                  4  55.704315  37.506584               3           72
# 132244                  4  55.699863  37.939564               3          480
# 132245                  4  55.862133  37.689613               3          128
#
#         floors_total  has_elevator
# 0                 12             1
# 1                 10             1
# 2                 10             1
# 3                 17             1
# 4                  9             1
# ...              ...           ...
# 132241            25             1
# 132242             5             0
# 132243             9             1
# 132244            25             1
# 132245            17             1
#
# [132246 rows x 18 columns]

# %% [markdown]
# # Выбросы

# %%
df.describe()
# Out:
#              flat_id          floor   is_apartment   kitchen_area  \
# count  132246.000000  132246.000000  132246.000000  132246.000000
# mean    69445.138666       7.455651       0.009603       8.964356
# std     40816.929668       5.703849       0.097525       5.212305
# min         0.000000       1.000000       0.000000       0.000000
# 25%     33979.250000       3.000000       0.000000       6.100000
# 50%     68861.500000       6.000000       0.000000       8.700000
# 75%    104761.750000      10.000000       0.000000      10.200000
# max    141361.000000      56.000000       1.000000     203.000000
#
#          living_area          rooms    studio     total_area         price  \
# count  132246.000000  132246.000000  132246.0  132246.000000  1.322460e+05
# mean       30.990703       2.124200       0.0      62.038371  1.933210e+07
# std        23.667590       0.990495       0.0      39.784039  6.757713e+07
# min         0.000000       1.000000       0.0      11.000000  1.100000e+01
# 25%        19.000000       1.000000       0.0      39.200001  8.900000e+06
# 50%        29.400000       2.000000       0.0      52.900002  1.180000e+07
# 75%        41.000000       3.000000       0.0      71.699997  1.685000e+07
# max       700.000000      20.000000       0.0     960.299988  9.873738e+09
#
#          building_id     build_year  building_type_int       latitude  \
# count  132246.000000  132246.000000      132246.000000  132246.000000
# mean    14017.299760    1986.492476           3.241240      55.730344
# std      6974.598002      22.067968           1.459392       0.102887
# min         1.000000    1901.000000           0.000000      55.211460
# 25%      8509.000000    1969.000000           2.000000      55.653915
# 50%     14300.000000    1985.000000           4.000000      55.724754
# 75%     20409.000000    2007.000000           4.000000      55.808098
# max     24620.000000    2023.000000           6.000000      56.011032
#
#            longitude  ceiling_height    flats_count   floors_total  \
# count  132246.000000   132246.000000  132246.000000  132246.000000
# mean       37.589355        2.952452     251.587723      14.077605
# std         0.150453        0.266027     206.994097       6.881819
# min        36.864372        2.000000       1.000000       1.000000
# 25%        37.491764        3.000000     111.000000       9.000000
# 50%        37.581272        3.000000     199.000000      14.000000
# 75%        37.692499        3.000000     323.000000      17.000000
# max        37.946411       27.000000    4455.000000      99.000000
#
#         has_elevator
# count  132246.000000
# mean        0.896866
# std         0.304134
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# В таких колонках как 'kitchen_area', 'living_area', 'total_area', 'price', 'ceiling_height' есть выбросы, напишем функцию для их удаления.

# %%
def remove_outliers(data: pd.DataFrame):
    outliers_cols = ['kitchen_area', 'living_area', 'total_area', 'price', 'ceiling_height']
    threshold = 1.5
    potential_outliers = pd.DataFrame()

    for col in outliers_cols:
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        margin = threshold * IQR
        lower = Q1 - margin
        upper = Q3 + margin
        potential_outliers[col] = ~data[col].between(lower, upper)

    outliers = potential_outliers.any(axis=1)
    data = data[~outliers].reset_index(drop=True)

    return data

# %%
df = remove_outliers(df)

# %%
df
# Out:
#         flat_id  floor  is_apartment  kitchen_area  living_area  rooms  \
# 0             0      9             0           9.9    19.900000      1
# 1             1      7             0           0.0    16.600000      1
# 2             2      9             0           9.0    32.000000      2
# 3             3      1             0          10.1    43.099998      3
# 4             4      3             0           3.0    14.000000      1
# ...         ...    ...           ...           ...          ...    ...
# 107136   141356      8             0           6.0    42.000000      3
# 107137   141357     16             0          11.0    18.000000      1
# 107138   141359      7             0           5.3    20.000000      1
# 107139   141360     15             0          13.8    33.700001      2
# 107140   141361     16             0           7.6    18.000000      1
#
#         studio  total_area     price  building_id  build_year  \
# 0            0   35.099998   9500000         6220        1965
# 1            0   43.000000  13500000        18012        2001
# 2            0   56.000000  13500000        17821        2000
# 3            0   76.000000  20000000        18579        2002
# 4            0   24.000000   5200000         9293        1971
# ...        ...         ...       ...          ...         ...
# 107136       0   64.000000  10800000         9503        1971
# 107137       0   42.000000  10500000        22455        2013
# 107138       0   31.500000   9700000         6513        1966
# 107139       0   65.300003  11750000        23952        2017
# 107140       0   38.000000   8000000        15104        1988
#
#         building_type_int   latitude  longitude  ceiling_height  flats_count  \
# 0                       6  55.717113  37.781120               3           84
# 1                       2  55.794849  37.608013               3           97
# 2                       4  55.740040  37.761742               3           80
# 3                       4  55.672016  37.570877               3          771
# 4                       1  55.808807  37.707306               3          208
# ...                   ...        ...        ...             ...          ...
# 107136                  4  55.740402  37.834579               3          428
# 107137                  4  55.626579  37.313503               3          672
# 107138                  4  55.704315  37.506584               3           72
# 107139                  4  55.699863  37.939564               3          480
# 107140                  4  55.862133  37.689613               3          128
#
#         floors_total  has_elevator
# 0                 12             1
# 1                 10             1
# 2                 10             1
# 3                 17             1
# 4                  9             1
# ...              ...           ...
# 107136             9             1
# 107137            25             1
# 107138             9             1
# 107139            25             1
# 107140            17             1
#
# [107141 rows x 18 columns]

# %% [markdown]
# # Проверка наличия очищенной таблицы в базе

# %%
df_clean = pd.read_sql('select * from clean_flats_buildings', dst_conn)

# %%
df_clean
# Out:
#         flat_id  floor  is_apartment  kitchen_area  living_area  rooms  \
# 0             0      9             0           9.9    19.900000      1
# 1             1      7             0           0.0    16.600000      1
# 2             2      9             0           9.0    32.000000      2
# 3             3      1             0          10.1    43.099998      3
# 4             4      3             0           3.0    14.000000      1
# ...         ...    ...           ...           ...          ...    ...
# 107136   141356      8             0           6.0    42.000000      3
# 107137   141357     16             0          11.0    18.000000      1
# 107138   141359      7             0           5.3    20.000000      1
# 107139   141360     15             0          13.8    33.700001      2
# 107140   141361     16             0           7.6    18.000000      1
#
#         studio  total_area     price  building_id  build_year  \
# 0            0   35.099998   9500000         6220        1965
# 1            0   43.000000  13500000        18012        2001
# 2            0   56.000000  13500000        17821        2000
# 3            0   76.000000  20000000        18579        2002
# 4            0   24.000000   5200000         9293        1971
# ...        ...         ...       ...          ...         ...
# 107136       0   64.000000  10800000         9503        1971
# 107137       0   42.000000  10500000        22455        2013
# 107138       0   31.500000   9700000         6513        1966
# 107139       0   65.300003  11750000        23952        2017
# 107140       0   38.000000   8000000        15104        1988
#
#         building_type_int   latitude  longitude  ceiling_height  flats_count  \
# 0                       6  55.717113  37.781120               3           84
# 1                       2  55.794849  37.608013               3           97
# 2                       4  55.740040  37.761742               3           80
# 3                       4  55.672016  37.570877               3          771
# 4                       1  55.808807  37.707306               3          208
# ...                   ...        ...        ...             ...          ...
# 107136                  4  55.740402  37.834579               3          428
# 107137                  4  55.626579  37.313503               3          672
# 107138                  4  55.704315  37.506584               3           72
# 107139                  4  55.699863  37.939564               3          480
# 107140                  4  55.862133  37.689613               3          128
#
#         floors_total  has_elevator
# 0                 12             1
# 1                 10             1
# 2                 10             1
# 3                 17             1
# 4                  9             1
# ...              ...           ...
# 107136             9             1
# 107137            25             1
# 107138             9             1
# 107139            25             1
# 107140            17             1
#
# [107141 rows x 18 columns]
